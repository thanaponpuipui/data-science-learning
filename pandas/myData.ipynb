# %% [markdown]
# ## Start my Cash-Note data project with pandas
# use mongodb database cash-note in model to test analysis functionality in jupyter notebook

# %%
# import pandas
import pandas as pd

# %%
# test data csv
note_data = pd.read_csv('../data/test.csv')

# %%
note_data
# Out:
#                                           item    price  \
# 0                                  Jetson Nano  3689.00
# 1   Jetson nano 2.1mm jack switch power supply   499.00
# 2           Sandisk extreme microSD UHS-1 64GB   528.00
# 3                            traveling(ticket)  1797.02
# 4                                Grocery items   171.00
# 5                                 2 kapao rice   186.00
# 6                                      sneaker   999.00
# 7                 green tea seed sleeping mask   720.00
# 8                  uniqlo airism home wear set   790.00
# 9                                grocery items   120.00
# 10                                      dinner    50.00
# 11             David Beckham's deodorant spray   199.00
# 12          Baby mild body lotion sakura white   110.00
# 13            chocolate milk with milk pudding    60.00
# 14                                       lunch   100.00
# 15                   Mint nose pepermint field    25.00
#
# ...

# %%
note_data['price'].dtype
# Out:
# dtype('float64')

# %%
note_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   item    16 non-null     object
#  1   price   16 non-null     float64
#  2   source  16 non-null     object
#  3   note    11 non-null     object
#  4   date    15 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 768.0+ bytes

# %% [markdown]
# ### All of the exercise before can also be done in database query(sql, mongodb)
# Find functionality that pandas give that does give benefit to user.
# One of the biggest is Python, so we can use other tool in python with our data.
#  - Numpy
#  - Matplotlib
#  - other matchine learning algorithm and other math and data related.
#  - can also use in application that made using python.
